# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# To develop a model to predict loan amount given the following attributes:
# - Customer Name
# - Customer e-mail
# - Country
# - Gender
# - Age
# - Annual Salary
# - Credit Card Debt
# - Net Worth
#
# The model should predict:
# - Loan Amount

# %% [markdown]
# # LIBRARIES IMPORT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # STEP1: IMPORT DATASET

# %%
loan_df = pd.read_csv('Customer Data.csv', encoding='ISO-8859-1')

# %%
loan_df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# 5       Carla Hester                                 mi@Aliquamerat.edu
# 6     Griffin Rivera                                  vehicula@at.co.uk
# 7         Orli Casey    nunc.est.mollis@Suspendissetristiqueneque.co.uk
# 8       Marny Obrien                        Phasellus@sedsemegestas.org
# 9      Rhonda Chavez                                    nec@nuncest.com
# 10       Jerome Rowe                               ipsum.cursus@dui.org
# 11      Akeem Gibson                     turpis.egestas.Fusce@purus.edu
# ...

# %% [markdown]
# # STEP2: VISUALIZE DATASET

# %%
sns.pairplot(loan_df)

# %% [markdown]
# # STEP3: CREATE TESTING AND TRAINING DATASET/DATA CLEANING

# %%
X = loan_df.drop(['Customer Name', 'Customer e-mail', 'Country', 'Loan Amount'], axis = 1)

# %%
X
# Out:
#      Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# 5         1  56.824893    68499.85162      14179.472440  428485.3604
# 6         1  46.607315    39814.52200       5958.460188  326373.1812
# 7         1  50.193016    51752.23445      10985.696560  629312.4041
# 8         0  46.584745    58139.25910       3440.823799  630059.0274
# 9         1  43.323782    53457.10132      12884.078680  476643.3544
# 10        1  50.129923    73348.70745       8270.707359  612738.6171
# 11        1  53.180158    55421.65733      10014.969290  293862.5123
# 12        0  44.396494    37336.33830      10218.320920  430907.1673
# ...

# %%
y = loan_df['Loan Amount']

# %%
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
# 5      56611.99784
# 6      28925.70549
# 7      47434.98265
# 8      48013.61410
# 9      38189.50601
# 10     59045.51309
# 11     42288.81046
# 12     28700.03340
# 13     49258.87571
# 14     49510.03356
# 15     53017.26723
# 16     41814.72067
# 17     43901.71244
# 18     44633.99241
# 19     54827.52403
# 20     51130.95379
# 21     43402.31525
# 22     47240.86004
# 23     46635.49432
# 24     45078.40193
# 25     44387.58412
# 26     37161.55393
# 27     49091.97185
# 28     58350.31809
# 29     43994.35972
#           ...
# 470    69669.47402
# 471    48052.65091
# 472    37364.23474
# 473    44500.81936
# 474    35139.24793
# 475    55167.37361
# 476    48383.69071
# 477    35823.55471
# 478    36517.70996
# 479    53110.88052
# 480    53049.44567
# 481    21471.11367
# 482    45015.67953
# 483    55377.87697
# 484    56510.13294
# 485    47443.74443
# ...

# %%
X.shape
# Out:
# (500, 5)

# %%
y.shape
# Out:
# (500,)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_x = MinMaxScaler()
X_scaled = scaler_x.fit_transform(X)

# %%
scaler_x.data_max_
# Out:
# array([1.e+00, 7.e+01, 1.e+05, 2.e+04, 1.e+06])

# %%
scaler_x.data_min_
# Out:
# array([    0.,    20., 20000.,   100., 20000.])

# %%
print(X_scaled)
# Out:
# [[0.         0.4370344  0.53515116 0.57836085 0.22342985]
#  [0.         0.41741247 0.58308616 0.476028   0.52140195]
#  [1.         0.46305795 0.42248189 0.55579674 0.63108896]
#  ...
#  [1.         0.67886994 0.61110973 0.52822145 0.75972584]
#  [1.         0.78321017 0.37264988 0.69914746 0.3243129 ]
#  [1.         0.53462305 0.51713347 0.46690159 0.45198622]]

# %%
X_scaled.shape
# Out:
# (500, 5)

# %%
y.shape
# Out:
# (500,)

# %%
y = y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (500, 1)

# %%
y
# Out:
# array([[35321.45877],
#        [45115.52566],
#        [42925.70921],
#        [67422.36313],
#        [55915.46248],
#        [56611.99784],
#        [28925.70549],
#        [47434.98265],
#        [48013.6141 ],
#        [38189.50601],
#        [59045.51309],
#        [42288.81046],
#        [28700.0334 ],
#        [49258.87571],
#        [49510.03356],
#        [53017.26723],
#        [41814.72067],
#        [43901.71244],
#        [44633.99241],
#        [54827.52403],
#        [51130.95379],
#        [43402.31525],
#        [47240.86004],
#        [46635.49432],
#        [45078.40193],
#        [44387.58412],
#        [37161.55393],
#        [49091.97185],
#        [58350.31809],
#        [43994.35972],
#        [17584.56963],
#        [44650.36073],
#        [66363.89316],
#        [53489.46214],
#        [39810.34817],
#        [51612.14311],
#        [38978.67458],
#        [10092.22509],
#        [35928.52404],
#        [54823.19221],
#        [45805.67186],
# ...

# %%
scaler_y = MinMaxScaler()

y_scaled = scaler_y.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.37072477],
#        [0.50866938],
#        [0.47782689],
#        [0.82285018],
#        [0.66078116],
#        [0.67059152],
#        [0.28064374],
#        [0.54133778],
#        [0.54948752],
#        [0.4111198 ],
#        [0.70486638],
#        [0.46885649],
#        [0.27746526],
#        [0.56702642],
#        [0.57056385],
#        [0.61996151],
#        [0.46217916],
#        [0.49157341],
#        [0.50188722],
#        [0.64545808],
#        [0.59339372],
#        [0.48453965],
#        [0.53860366],
#        [0.53007738],
#        [0.50814651],
#        [0.49841668],
#        [0.3966416 ],
#        [0.56467566],
#        [0.6950749 ],
#        [0.49287831],
#        [0.12090943],
#        [0.50211776],
#        [0.80794216],
#        [0.62661214],
#        [0.43394857],
#        [0.60017103],
#        [0.42223485],
#        [0.01538345],
#        [0.37927499],
#        [0.64539707],
#        [0.51838974],
#        [0.45869677],
#        [0.26804521],
# ...

# %% [markdown]
# # STEP4: TRAINING THE MODEL

# %%
X_scaled.shape
# Out:
# (500, 5)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
X_test.shape
# Out:
# (125, 5)

# %%
X_train.shape
# Out:
# (375, 5)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(40, input_dim=5, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\sneha\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 40)                240
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 41
# ...
# Total params: 1,921
# Trainable params: 1,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs=100, batch_size=50,  verbose=1, validation_split=0.2)
# Out:
# Train on 300 samples, validate on 75 samples
# Epoch 1/100
# 300/300 [==============================] - 0s 593us/sample - loss: 0.1072 - val_loss: 0.0589
# Epoch 2/100
# 300/300 [==============================] - 0s 72us/sample - loss: 0.0472 - val_loss: 0.0268
# Epoch 3/100
# 300/300 [==============================] - 0s 65us/sample - loss: 0.0229 - val_loss: 0.0254
# Epoch 4/100
# 300/300 [==============================] - 0s 114us/sample - loss: 0.0220 - val_loss: 0.0263
# Epoch 5/100
# 300/300 [==============================] - 0s 65us/sample - loss: 0.0187 - val_loss: 0.0206
# Epoch 6/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.0138 - val_loss: 0.0170
# Epoch 7/100
# 300/300 [==============================] - 0s 62us/sample - loss: 0.0128 - val_loss: 0.0161
# Epoch 8/100
# 300/300 [==============================] - 0s 122us/sample - loss: 0.0119 - val_loss: 0.0152
# Epoch 9/100
# ...

# %% [markdown]
# # STEP#5: EVALUATING THE MODEL

# %%
print(epochs_hist.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progression During Training/Validation')
plt.ylabel('Training and Validation Losses')
plt.xlabel('Epoch Number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# Gender, Age, Annual Salary, Credit Card Debt, Net Worth 
X_test = np.array([[1, 50,  50000, 10000, 600000]])

y_predict = model.predict(X_test)

print('Expected Loan Amount=', y_predict)
# Out:
# Expected Loan Amount= [[277902.66]]

# %%
from sklearn.metrics import r2_score
import matplotlib.pyplot as pl  
t1 = test_data[Loan Amount]
t2 = test_data[y_predict]
r2_value = r2_score(t1,t2)
# Out:
#   File "<ipython-input-35-e8536cbc4a36>", line 3
#     t1 = test_data[Loan Amount]
#                              ^
# SyntaxError: invalid syntax
